# %% [markdown]
# # 인터넷 상의 데이터 읽기
# pandas.read_csv(url)
# 크롤링 통해 일기 selenium라이브러리 읽기
# pandas.read_html(url,)
# datareader라이브러리-내부적으로 requests 라이브러리 활용
# seaborn 라이브러리

# %%
import pandas as pd

# %% [markdown]
# ## pandas.read_csv(url)

# %%
df = pd.read_csv('https://people.sc.fsu.edu/~jburkardt/data/csv/biostats.csv', index_col = 'Name')
print(df.shape)
df.head()
# Out:
# (18, 4)
#            "Sex"   "Age"   "Height (in)"   "Weight (lbs)"
# Name
# Alex         "M"      41              74              170
# Bert         "M"      42              68              166
# Carl         "M"      32              70              155
# Dave         "M"      39              72              167
# Elly         "F"      30              66              124

# %%
# loc 인덴서 활용 / 행 불러오기
df.loc['Alex']
# Out:
#      "Sex"                "M"
#  "Age"                     41
#  "Height (in)"             74
#  "Weight (lbs)"           170
# Name: Alex, dtype: object

# %% [markdown]
# ## pandas.read_html 이용하기

# %%
df_list = pd.read_html('https://astro.kasi.re.kr/life/pageView/5')

# %%
len(df_list)
# Out:
# 1

# %%
df = df_list[0]
df.head()
# Out:
#              ìë ¥      ìë ¥  \
# 0  2020-04-01 (ì)  2020-03-09
# 1  2020-04-02 (ëª©)  2020-03-10
# 2  2020-04-03 (ê¸)  2020-03-11
# 3  2020-04-04 (í )  2020-03-12
# 4  2020-04-05 (ì¼)  2020-03-13
#
#                                         ìë ¥ê°ì§
# 0  ê²½ì(åºå­)ë
#  ê²½ì§(åºè¾°)ì ê°ì (ç²...
# 1  ê²½ì(åºå­)ë
#  ê²½ì§(åºè¾°)ì ìí´(ä¹...
# 2  ê²½ì(åºå­)ë
#  ê²½ì§(åºè¾°)ì ë³ì(ä¸...
# 3  ê²½ì(åºå­)ë
#  ê²½ì§(åºè¾°)ì ì ì¶(ä¸...
# 4  ê²½ì(åºå­)ë
#  ê²½ì§(åºè¾°)ì ë¬´ì¸(æ...

# %%
# pip install --upgrade pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## pandas_datareader

# %%
# 주식정보

import pandas_datareader as pdr
pdr.get_data_yahoo('035420.KS', '2020-01-01')
# Out:
#                 High       Low      Open     Close    Volume  Adj Close
# Date
# 2020-01-02  188000.0  182000.0  187500.0  182500.0  300640.0   182500.0
# 2020-01-03  186000.0  180500.0  185000.0  181500.0  454492.0   181500.0
# 2020-01-06  182000.0  178000.0  180000.0  180500.0  287970.0   180500.0
# 2020-01-07  187000.0  181500.0  182500.0  187000.0  328624.0   187000.0
# 2020-01-08  183500.0  179000.0  182000.0  183000.0  820867.0   183000.0
# 2020-01-09  186500.0  183500.0  183500.0  186000.0  531355.0   186000.0
# 2020-01-10  188000.0  184000.0  185000.0  188000.0  398739.0   188000.0
# 2020-01-13  188500.0  186000.0  187500.0  188000.0  337749.0   188000.0
# 2020-01-14  194500.0  188000.0  188000.0  190500.0  501286.0   190500.0
# 2020-01-15  192000.0  188500.0  189500.0  191500.0  323778.0   191500.0
# 2020-01-16  192500.0  189000.0  190000.0  191500.0  245107.0   191500.0
# 2020-01-17  192500.0  189500.0  190500.0  191000.0  286019.0   191000.0
# ...
